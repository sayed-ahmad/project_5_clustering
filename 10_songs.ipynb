# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\User\2_spotify_10_songs.csv", index_col= 0, skipinitialspace=True)
data
# Out:
#                                                     artist                 \
# song_name                                      ...
# My Band                                        ...  D12
# The Real Slim Shady                            ...  Eminem
# Águas De Março                                 ...  Antônio Carlos Jobim
# The Girl From Ipanema                          ...  Stan Getz
# Paint It, Black                                ...  The Rolling Stones
# Sultans Of Swing                               ...  Dire Straits
# Space Raiders - Charlotte de Witte Remix       ...  Eats Everything
# In Silence                                     ...  Amelie Lens
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...  Johannes Brahms
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...  Frédéric Chopin
#
#                                                     danceability   energy    \
# song_name                                      ...
# ...

# %%
data.columns
data.columns = data.columns.str.strip()

# %%
data['id']
# Out:
# song_name
# My Band                                                                     4XHQyvbrBsQaaBUW1VvmsL
# The Real Slim Shady                                                         3yfqSUWxFvZELEM4PmlwIR
# Águas De Março                                                              1y7OxO5i6sfrHXAmUM77YG
# The Girl From Ipanema                                                       3898C4AbdbptwYet6547e5
# Paint It, Black                                                             63T7DJ1AFDD6Bn8VzG6JE8
# Sultans Of Swing                                                            6cr6UDpkjEaMQ80OjWqEBQ
# Space Raiders - Charlotte de Witte Remix                                    4F8OK7mNa51mKqgHqWQiYm
# In Silence                                                                  2vfSCFvMbpf4hwxt22Wx7b
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and Piano) [Brahms Lullaby]       59cPOVxrn3Yjwydl1pullI
# ...

# %%
data.columns
# Out:
# Index(['artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'id', 'html'],
#       dtype='object')

# %%
to_drop = ['artist', 'key','mode','duration_ms','time_signature', 'id', 'html']
data = data.drop(columns=to_drop,)
data
# Out:
#                                                     danceability   energy  \
# song_name                                      ...
# My Band                                        ...         0.851  0.84900
# The Real Slim Shady                            ...         0.949  0.66100
# Águas De Março                                 ...         0.642  0.33900
# The Girl From Ipanema                          ...         0.641  0.14000
# Paint It, Black                                ...         0.464  0.79500
# Sultans Of Swing                               ...         0.733  0.79400
# Space Raiders - Charlotte de Witte Remix       ...         0.749  0.73100
# In Silence                                     ...         0.736  0.84500
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...         0.184  0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...         0.387  0.04510
#
#                                                     loudness  speechiness  \
# ...

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data)

# %%
from sklearn.cluster import KMeans

random_seed = 123

my_kmeans = KMeans(n_clusters=4, random_state=random_seed)
my_kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=4, random_state=123)

# %%
labels = my_kmeans.labels_

# Plot the points colored by cluster
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='viridis', s=50)

# Plot the cluster centroids
centroids = my_kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='X')

plt.title("KMeans Clusters")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
plt.scatter(x = data.iloc[:, 0],
            y = data.iloc[:, 1],
            c = my_2d_kmeans.labels_,
            cmap = 'viridis')

# Annotate the data points
for idx, row in two_features_df.iterrows():
    plt.annotate(idx, (row["broccoli"], row["brussels_sprouts"]), xytext=(5, 0), textcoords='offset points')

# Add labels and title
plt.title('KMeans Clustering')
plt.xlabel(two_features_df.columns[0])
plt.ylabel(two_features_df.columns[1])

# Display the plot
plt.show()

# %%
full_table = my_kmeans.labels_
data['cluster'] = full_table
data.sort_values(by='cluster', ascending=True)
# Out:
#                                                     danceability   energy  \
# song_name                                      ...
# Space Raiders - Charlotte de Witte Remix       ...         0.749  0.73100
# In Silence                                     ...         0.736  0.84500
# My Band                                        ...         0.851  0.84900
# The Real Slim Shady                            ...         0.949  0.66100
# The Girl From Ipanema                          ...         0.641  0.14000
# Águas De Março                                 ...         0.642  0.33900
# Sultans Of Swing                               ...         0.733  0.79400
# Paint It, Black                                ...         0.464  0.79500
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...         0.184  0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...         0.387  0.04510
#
#                                                     loudness  speechiness  \
# ...
